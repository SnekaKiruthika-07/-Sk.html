# %% [markdown]
# <a href="https://colab.research.google.com/github/SnekaKiruthika-07/-Sk.html/blob/main/datavisulzation%20techiques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the GeoJSON dataset
geojson_path = '/content/export (16) (1).geojson'
gdf = gpd.read_file(geojson_path)
plt.figure(figsize=(10, 6))
sns.countplot(x='type', data=gdf)
plt.title('Type Distribution')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()
